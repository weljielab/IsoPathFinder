# %%
################################################################################
#Using calculated isotopomer paths, two main approaches of trimming will be used
#1) Using circadian EC hits from Xu, 2011 and Gill, 2015, to pull out any rows
#...which contain any ECs, and the number of ECs in a row given will also be added
#
#2) Gibbs energies have been estimated in Tepper, 2013, which will be used to 
#...predict path thermodynamics
#
#Note this is an optional script, and an example of how one may go about trimming
#.. excess results through other means, such as previously published 'omic data
#.. or reaction thermodynamics
#
#This script should be used as a guide, as the trimming procedures can be very
#.. dependent on context and experimental objectives
################################################################################

# %%
import numpy
import pandas
import os
import sys
import re
import itertools
import csv
from itertools import chain, repeat
from collections import defaultdict
import dill as pickle
from pathos.helpers import mp

# %%
#Read in a list of significant circadian ECs from Xu et al, 2011 and Gill et al, 2015
SigECList=pandas.read_csv('Xu2011Gill2015_ECs_Cyclers.csv',header=None)
ECList=list(SigECList[0])

#Edit names to match the format of the PathSearch results
ECList=['EC-'+x for x in ECList]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d952a261bb7e> in <module>()
#       1 #Read in a list of significant circadian ECs from Xu et al, 2011 and Gill et al, 2015
# ----> 2 SigECList=pandas.read_csv('Xu2011Gill2015_ECs_Cyclers.csv',header=None)
#       3 ECList=list(SigECList[0])
#       4
#       5 #Edit names to match the format of the PathSearch results
#
# /home/sethpy/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /home/sethpy/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /home/sethpy/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /home/sethpy/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /home/sethpy/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# FileNotFoundError: File b'Xu2011Gill2015_ECs_Cyclers.csv' does not exist

# %%
#Read in the list of estimated Gibbs energies for all annotated enzymes, from Tepper et al., 2013
GibbsList=pandas.read_csv('Tepper2013_GibbsECs.csv',skiprows=1)
GibbsECList=['EC-'+x for x in list(GibbsList['ec number'])]
#Note this will take the last delta G value in a list of duplicated ECs

GibbsListDict=dict(zip(GibbsECList,GibbsList['standart Gibbs energy (kJ/mol)']))

# %%
#Read in the results of the isotopologue file of interest
#GlnDF=pandas.read_csv('Glutamine M+2_Paths_13Rxns.csv',header=None,error_bad_lines=False)
#SerDF=pandas.read_csv('Serine M+3_Paths_9Rxns.csv',header=None,error_bad_lines=False)
#GSHDF=pandas.read_csv('Glutathione Reduced M+2_Paths_9Rxns.csv',header=None,error_bad_lines=False)

# %%
#From the fly studies, drop any paths which don't have circadian enzymes
#NOTE!# This step is optional, it is entirely possible that pathway activities may be cyclic without a circadian enzyme (for more detail, see Thurley et al, PNAS, 2017)

def KeggECTrimmer(RowItem,RxnNumber):
    #Convert the stringy EC item into a list of one/multiple ECs
    ListyECs=[re.sub('\[|\'|\]','',x) for x in re.split('\, ',RowItem)]
    
    #if any item across the row is found in the circadian enzyme list
    if any([y for y in ListyECs if y in KeggECList]):
        RowItem=[y for y in ListyECs if y in KeggECList]
        return(RowItem)
    else:
        return(RxnNumber)

# %%
#Find ECs for reporting - if there isn't an EC (say only a Metacyc RXN is left), it can be dropped - of course the 'RXN' format in MetaCyc may represent real reactions, but if it isn't connection to an EC the interpretation is more difficult
def MatchFlyKeggECs(PathMatrix):
    DropIndices=[]
    for rxn in range(len(PathMatrix)):
        ECMatchList=[KeggECTrimmer(z,rxn) for z in PathMatrix[rxn:rxn+1].values[0] if type(z) is str and 'EC' in z]
        if any([x==rxn for x in ECMatchList]):
            DropIndices.append(rxn)
            
    #Store indicies where there isn't a RXN -> EC conversion
    PathMatrix=PathMatrix.drop(DropIndices)
    PathMatrix=PathMatrix.reset_index(drop=True)
    return(PathMatrix)

# %%
#Sum up the gibbs energies for a given metabolic path
def SumGibbsAcrossRow(PathMatrix):
    MiniGibbList=[]
    for items in PathMatrix:

        try:
            if any([GibbsListDict[x] for x in GibbsECList if x in re.split('\'|\,',items)]):
                
                MiniGibbList.append(min([GibbsListDict[x] for x in GibbsECList if x in re.split('\'|\,',items)]))
        except:
            pass
        
    PathMatrix['Gibbs Sum']=sum(MiniGibbList)
    return(PathMatrix)

# %%
#Match ECs in isotopomer paths to significant EC hits from Xu,2011 and Gill,2015
def CircadianECCounter(PathMatrix):
    
    TempECList=[]
    
    for items in PathMatrix:
        
        try:
            
            if any([x for x in ECList if x in re.split('\'|\,',items)])==True:
                    
                    #Add the EC to the list
                TempECList.extend([x for x in ECList if x in re.split('\'|\,',items)])
                    
        except:
            pass
    
    #Only unique items in the ECList
    TempECList=list(set(TempECList))
    
    PathMatrix['Number of Circadian ECs']=len(TempECList)
    PathMatrix['Circadian ECs']=TempECList
    
    return(PathMatrix)

# %%
#Function to find ECs in the PathMatrix which match to Xu,2011 and Gill,2015 circadian hits
#This function is currently very slow for large data frames
#Converted to apply functions to take out loops and still slow, some optimization may be required
def MatchCircadianECHitsAndGetGibbs(PathMatrix):
    
    PathMatrix=PathMatrix.reset_index(drop=True)
    
    #Drop duplicates
    PathMatrix=PathMatrix.drop_duplicates()
    
    PathMatrix=PathMatrix.reset_index(drop=True)
    
    #ECs added
    PathMatrixECs=PathMatrix.apply(CircadianECCounter,axis=1)
    
    #Caculate Gibbs across each path
    PathMatrix=PathMatrix.apply(SumGibbsAcrossRow,axis=1)

    
    PathMatrix['Number of Circadian ECs']=PathMatrixECs['Number of Circadian ECs']
    PathMatrix['Circadian ECs']=PathMatrixECs['Circadian ECs']
    
    #Drop rows which don't match any ECs (optional)
    PathMatrixDrop=PathMatrix[PathMatrix['Number of Circadian ECs']!=0]
    #PathMatrixDrop=PathMatrix
    
    PathMatrixDrop=PathMatrixDrop.reset_index(drop=True)
    
    ##Sort by number of matches
    ##PathMatrixDrop=PathMatrixDrop.sort_values('Gibbs Sum',ascending=True)
    
    #Drop certain unwanted items
    PathMatrixDrop=DropSpecifics(PathMatrixDrop)
    
    PathMatrixDrop=PathMatrixDrop.reset_index(drop=True)
    
    return(PathMatrixDrop)

# %%
#Drop certain metabolites that aren't relevant or don't match beyond a PubChem ID
#More features can be added here depending on the organism, experimenters' needs etc..
#This is very slow, may need a new way to do this
def DropSpecifics(PathMatrix):
    
    #Regex for certain ECs
    EC1=re.compile('\[\'EC-4.1.2.22\'\]')
    EC2=re.compile('\[\'EC-4.1.2.9\'\]')
    EC3=re.compile('\'EC-4.1.1.39\'')
    
    DropIndex=[]
    for rxn in range(len(PathMatrix)):
        if any([x for x in PathMatrix[rxn:rxn+1].values[0] if type(x) is str and 'Sorbose' in x]):
            DropIndex.append(rxn)
        if any([x for x in PathMatrix[rxn:rxn+1].values[0] if type(x) is str and 'AC1L1ARE' in x]):
            DropIndex.append(rxn)
        if any([x for x in PathMatrix[rxn:rxn+1].values[0] if type(x) is str and EC1.search(x)]):
            DropIndex.append(rxn)
        if any([x for x in PathMatrix[rxn:rxn+1].values[0] if type(x) is str and EC2.search(x)]):
            DropIndex.append(rxn)
        if any([x for x in PathMatrix[rxn:rxn+1].values[0] if type(x) is str and EC3.search(x)]):
            DropIndex.append(rxn)
    DropIndex=list(set(DropIndex))
    PathMatrix=PathMatrix.drop(DropIndex)
    PathMatrix=PathMatrix.reset_index(drop=True)
    
    return(PathMatrix)

# %%
#Making DropSpecifics parallel
PathMatrixSplit=list(numpy.array_split(SerDF,16))
    
pooler=mp.Pool(16)
        
with open('Trimmed_Paths.csv','a') as fp: #originally 'w' - but append for looping through shorter path lengths
    #written out to file as its being built
        for result in pooler.imap(MatchCircadianECHitsAndGetGibbs,PathMatrixSplit):
            #Each result is a Pandas Object, so write it to csv
            result.to_csv(fp,index=False,header=False)

pooler.close()
pooler.join()

# %%
##Read back in to sort
##Sort by number of matches
SerDF=pandas.read_csv('Trimmed_Paths.csv',header=None)
SerDF=SerDF.sort_values(SerDF.columns[-3],ascending=True)
SerDF=SerDF.drop_duplicates()
SerDF=SerDF.reset_index(drop=True)
# Out:
#             0                1                          2   \
# 0   Serine M+3  ['EC-4.3.1.17']               Pyruvate M+3
# 1   Serine M+3  ['EC-4.3.1.17']               Pyruvate M+3
# 2   Serine M+3  ['EC-4.3.1.17']               Pyruvate M+3
# 3   Serine M+3  ['EC-4.3.1.17']               Pyruvate M+3
# 4   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 5   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 6   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 7   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 8   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 9   Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 10  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 11  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 12  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 13  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 14  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 15  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 16  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 17  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 18  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 19  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 20  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 21  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 22  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 23  Serine M+3  ['EC-2.6.1.45']  3-Hydroxypyruvic acid M+3
# 24  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 25  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 26  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 27  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 28  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 29  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 30  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
# 31  Serine M+3   ['EC-3.1.3.3']        3-Phosphoserine M+3
#
#                                             3                             4   \
# 0                              ['EC-2.7.1.40']       phosphoenolpyruvate M+3
# 1                              ['EC-2.7.1.40']       phosphoenolpyruvate M+3
# 2                              ['EC-2.7.1.40']       phosphoenolpyruvate M+3
# 3                              ['EC-2.7.1.40']       phosphoenolpyruvate M+3
# 4   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 5   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 6   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 7   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 8   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 9   ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 10                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 11  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 12  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 13  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 14                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 15                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 16  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 17  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 18  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 19  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 20                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 21                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 22                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 23  ['EC-1.1.1', 'EC-1.1.1.29', 'EC-1.1.1.81']                 Glycerate M+3
# 24                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 25                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 26                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 27                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 28                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 29                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 30                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
# 31                             ['EC-2.6.1.52']  3-Phosphohydroxypyruvate M+3
#
#                  5                           6                7   \
# 0   ['EC-4.2.1.11']  2-phosphoglyceric acid M+3  ['EC-5.4.2.12']
# 1   ['EC-4.2.1.11']  2-phosphoglyceric acid M+3  ['EC-5.4.2.12']
# 2   ['EC-4.2.1.11']  2-phosphoglyceric acid M+3  ['EC-5.4.2.12']
# 3   ['EC-4.2.1.11']  2-phosphoglyceric acid M+3  ['EC-5.4.2.12']
# 4   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 5   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 6   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 7   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 8   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 9   ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 10  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 11  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 12  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 13  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 14  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 15  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 16  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 17  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 18  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 19  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 20  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 21  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 22  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 23  ['EC-2.7.1.31']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 24  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 25  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 26  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 27  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 28  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 29  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 30  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
# 31  ['EC-1.1.1.95']      3-Phosphoglycerate M+3   ['EC-2.7.2.3']
#
#                              8                9        ...         \
# 0        3-Phosphoglycerate M+3   ['EC-2.7.2.3']       ...
# 1        3-Phosphoglycerate M+3   ['EC-2.7.2.3']       ...
# 2        3-Phosphoglycerate M+3   ['EC-2.7.2.3']       ...
# 3        3-Phosphoglycerate M+3   ['EC-2.7.2.3']       ...
# 4   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 5   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 6   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 7   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 8   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 9   1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 10  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 11  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 12  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 13  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 14  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 15  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 16  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 17  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 18  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 19  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 20  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 21  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 22  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 23  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 24  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 25  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 26  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 27  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 28  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 29  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 30  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
# 31  1,3-Bisphosphoglycerate M+3  ['EC-1.2.1.12']       ...
#
#                                     12               13  \
# 0           Glycerophosphoric acid M+3  ['EC-4.1.2.13']
# 1           Glycerophosphoric acid M+3  ['EC-4.1.2.13']
# 2           Glycerophosphoric acid M+3  ['EC-4.1.2.13']
# 3           Glycerophosphoric acid M+3  ['EC-4.1.2.13']
# 4   1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 5       Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 6   1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 7   1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 8   1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 9   1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 10  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 11      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 12  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 13  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 14      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 15  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 16      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 17  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 18  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 19  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 20  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 21  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.11']
# 22  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 23      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 24      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 25  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 26  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 27      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
# 28  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 29  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 30  1,6-di-o-phosphonohexopyranose M+6  ['EC-2.7.1.10']
# 31      Dihydroxyacetone Phosphate M+3  ['EC-4.1.2.13']
#
#                                     14                15  \
# 0   1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.11']
# 1   1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 2   1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 3   1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 4               Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 5   1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.11']
# 6               Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 7               Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 8               Hexose-6-Phosphate M+6    ['EC-5.4.2.6']
# 9               Hexose-1-Phosphate M+6    ['EC-5.4.2.5']
# 10              Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 11  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 12              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 13              Hexose-1-Phosphate M+6    ['EC-2.7.1.6']
# 14  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.11']
# 15              Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 16  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 17              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 18              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 19              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 20              Hexose-6-Phosphate M+6    ['EC-5.4.2.5']
# 21              Hexose-6-Phosphate M+6    ['EC-5.4.2.6']
# 22              Hexose-1-Phosphate M+6    ['EC-5.4.2.5']
# 23  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 24  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 25              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 26              Hexose-1-Phosphate M+6    ['EC-2.7.1.6']
# 27  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
# 28              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 29              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 30              Hexose-1-Phosphate M+6  ['EC-2.4.1.231']
# 31  1,6-di-o-phosphonohexopyranose M+6   ['EC-2.7.1.10']
#
#                         16                              17  \
# 0   Hexose-6-Phosphate M+6  ['EC-2.7.1.1', 'EC-2.7.1.147']
# 1   Hexose-1-Phosphate M+6                 ['EC-3.1.3.10']
# 2   Hexose-1-Phosphate M+6                  ['EC-2.7.1.6']
# 3   Hexose-1-Phosphate M+6                ['EC-2.4.1.231']
# 4   Hexose-1-Phosphate M+6                 ['EC-3.1.3.10']
# 5   Hexose-6-Phosphate M+6  ['EC-2.7.1.1', 'EC-2.7.1.147']
# 6   Hexose-1-Phosphate M+6                  ['EC-2.7.1.6']
# 7   Hexose-1-Phosphate M+6                ['EC-2.4.1.231']
# 8   Hexose-1-Phosphate M+6                 ['EC-2.4.1.64']
# 9   Hexose-6-Phosphate M+6  ['EC-2.7.1.1', 'EC-2.7.1.147']
# 10  Hexose-1-Phosphate M+6                 ['EC-3.1.3.10']
# 11  Hexose-1-Phosphate M+6                 ['EC-3.1.3.10']
# 12   alpha-D-Trehalose M+6                 ['EC-3.2.1.28']
# 13     alpha-D-Glucose M+6                  ['EC-5.1.3.3']
# 14  Hexose-6-Phosphate M+6  ['EC-2.7.1.1', 'EC-2.7.1.147']
# 15  Hexose-1-Phosphate M+6                  ['EC-2.7.1.6']
# 16  Hexose-1-Phosphate M+6                  ['EC-2.7.1.6']
# 17    D-(+)-Trehalose M+12                ['EC-2.4.1.231']
# 18     alpha-D-Glucose M+6                  ['EC-5.1.3.3']
# 19   alpha-D-Trehalose M+6                 ['EC-2.4.1.64']
# 20  Hexose-1-Phosphate M+6                ['EC-2.4.1.231']
# 21  Hexose-1-Phosphate M+6                 ['EC-2.4.1.64']
# 22  Hexose-6-Phosphate M+6  ['EC-2.7.1.1', 'EC-2.7.1.147']
# 23  Hexose-1-Phosphate M+6                ['EC-2.4.1.231']
# 24  Hexose-1-Phosphate M+6                 ['EC-3.1.3.10']
# 25   alpha-D-Trehalose M+6                 ['EC-3.2.1.28']
# 26     alpha-D-Glucose M+6                  ['EC-5.1.3.3']
# 27  Hexose-1-Phosphate M+6                  ['EC-2.7.1.6']
# 28     alpha-D-Glucose M+6                  ['EC-5.1.3.3']
# 29    D-(+)-Trehalose M+12                ['EC-2.4.1.231']
# 30   alpha-D-Trehalose M+6                 ['EC-2.4.1.64']
# 31  Hexose-1-Phosphate M+6                ['EC-2.4.1.231']
#
#                      18         19 20               21
# 0   alpha-D-Glucose M+6 -47.733063  1  ['EC-2.7.1.40']
# 1   alpha-D-Glucose M+6 -30.187252  1  ['EC-2.7.1.40']
# 2   alpha-D-Glucose M+6 -21.970038  1  ['EC-2.7.1.40']
# 3   alpha-D-Glucose M+6 -11.360571  1  ['EC-2.7.1.40']
# 4   alpha-D-Glucose M+6  -0.582832  0               []
# 5   alpha-D-Glucose M+6   7.158978  0               []
# 6   alpha-D-Glucose M+6   7.634382  0               []
# 7   alpha-D-Glucose M+6  18.243849  0               []
# 8   alpha-D-Glucose M+6  18.243849  0               []
# 9   alpha-D-Glucose M+6  20.410832  0               []
# 10  alpha-D-Glucose M+6  20.976302  0               []
# 11  alpha-D-Glucose M+6  24.704790  0               []
# 12  alpha-D-Glucose M+6  24.845720  0               []
# 13  alpha-D-Glucose M+6  26.904120  0               []
# 14  alpha-D-Glucose M+6  28.718113  0               []
# 15  alpha-D-Glucose M+6  29.193517  0               []
# 16  alpha-D-Glucose M+6  32.922004  0               []
# 17  alpha-D-Glucose M+6  37.513587  0               []
# 18  alpha-D-Glucose M+6  37.513587  0               []
# 19  alpha-D-Glucose M+6  37.513587  0               []
# 20  alpha-D-Glucose M+6  39.802984  0               []
# 21  alpha-D-Glucose M+6  39.802984  0               []
# 22  alpha-D-Glucose M+6  41.969967  0               []
# 23  alpha-D-Glucose M+6  43.531471  0               []
# 24  alpha-D-Glucose M+6  46.263924  0               []
# 25  alpha-D-Glucose M+6  46.404854  0               []
# 26  alpha-D-Glucose M+6  48.463255  0               []
# 27  alpha-D-Glucose M+6  54.481139  0               []
# 28  alpha-D-Glucose M+6  59.072722  0               []
# 29  alpha-D-Glucose M+6  59.072722  0               []
# 30  alpha-D-Glucose M+6  59.072722  0               []
# 31  alpha-D-Glucose M+6  65.090605  0               []
#
# [32 rows x 22 columns]
